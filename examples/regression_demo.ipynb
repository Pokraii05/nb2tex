# %% [markdown]
# # nb2tex Regression Demo
# This notebook intentionally contains patterns that often break TeX conversion.

# %% [markdown]
# ## Fit of phase shift $\phi(f)$ and φ(f) in an RLC circuit
# Heading with inline math to test section-title conversion.

# %% [markdown]
# Measured values are $R = 100 \Omega$, $C = 2.2 \mu F$ and $f = 1 \text{kHz}$.
# This line mixes text (R + X) and then (C) in one paragraph.

# %% [markdown]
# At high frequency the phase tends to 90 °, while at low frequency it tends to 0 °.
# Also expressed in math form: $90^\circ$.

# %%
R = 120
dR = 5
mu = 2.2e-6
print(f"R = {R} ± {dR} Ohm")
print(f"C = {mu} F (μ scale)")

# %%
import math
f = [10, 100, 1000]
phi = [math.degrees(math.atan(x / 100.0)) for x in f]
print("phi(deg)=", phi)
