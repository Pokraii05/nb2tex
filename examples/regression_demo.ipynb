# %% [markdown]
# # nb2tex Repro Cases
# Synthetic notebook containing exact markdown patterns that previously broke TeX conversion.

# %% [markdown]
# We arrive at values of $R_R = 109.5\Omega$, $R_L = 5.9\Omega $ and $C = 2.165 \mu F$.
# ...
# the Lissajous curve collapses into a line 45 $\degree$ tilted w.r.t to the x-axis.

# %% [markdown]
# If we let frequency $f \to \infty$, we see that the phase shift $\phi(f)$ tends to $0 \degree$ for the RC circuit and $90 \degree$ for the RL and RLC circuit.
#
# On the other hand, if we let frequency $f \to -\infty$, we see that the phase shift $\phi(f)$ tends to $90 \degree$ for the RC circuit and $0 \degree$ for the RL and RLC circuit.

# %% [markdown]
# Hence it is no surprise that the series resistance $ R = (108 \pm 5) \Omega$ acquired by the fitting procedure is almost equal to the measured value of the resistor resistance $R_R=(109.5 \pm 1.095) \Omega$.

# %% [markdown]
# ## Long Equation Split Demo
#
# The following equation is intentionally very long and should be auto-split at `=` into aligned rows while preserving one equation number in TeX output.
#
#
#
# $$
#
# Z_{RL} = \frac{i\omega L+R_{sp}}{1+i \omega C(i\omega L+R_{sp})} = \frac{i\omega L+R_{sp}}{1 - \omega^2LC + i \omega R_{sp}C} = \frac{(i\omega L+R_{sp})(1 - \omega^2LC - i \omega R_{sp}C)}{(1 - \omega^2LC)^2 + \omega^2 (R_{sp}C)^2} = \frac{R_{sp}+\omega^2 (R_{sp}LC-R_{sp}LC) + i\left( \omega L - \omega^3L^2C - \omega R_{sp}^2C\right)}{1  + \omega^2 \left((R_{sp}C)^2- 2LC \right)+ \omega^4L^2C^2}
#
# $$
